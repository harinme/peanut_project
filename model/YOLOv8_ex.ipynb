# %% [markdown]
# # Data Preparation

# %%
# 압축풀기
import  zipfile
with  zipfile.ZipFile( './peanut2.v2i.yolov8.zip')    as  target_file:
        target_file.extractall(  './peanuts' )

# %% [markdown]
# ### yaml 파일 설정 (데이터셋 위치 알려주는 config file)
# ##### roboflow 에서 제공되는 data.yaml 파일 확인

# %%
# yaml파일 내용 보기
# !cat ./peanuts/data.yaml
# Out:
# 'cat'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.

# %% [markdown]
# ### custom data에 대한 yaml 파일 만들기

# %%
# 코랩을 사용하기 때문에 코랩에 특화된 디렉토리로 변경해야 합니다
# !pip install PyYAML

# %%
# yaml 파일을 학습이 가능하도록 경로 설정.
# key-value 데이터인 dict 데이터타입으로 data['train'], data['val'], data['nc'], data['names'] 에 넣어주는데,
# 가장 중요한 부분은 데이터 경로 설정임.
# 코랩에 맞는 경로로 바꾸어줌

import yaml

data = { 'train' : './peanuts/train/images/',
         'val' : './peanuts/valid/images/',
         'test' : './peanuts/test/images',
         'names' :['peeled', 'unpeeled'],
         'nc' : 2 }

# yaml파일 쓰기
with  open(  './peanuts/peanut.yaml',     'w'     )    as  f :
        yaml.dump( data, f   )

# 위에서 쓴 yaml파일 열기
with  open( './peanuts/peanut.yaml',   'r'   )   as   f :
       peanut_yaml =  yaml.safe_load( f )
       display(  peanut_yaml )
# Out:
# {'names': ['peeled', 'unpeeled'],
#  'nc': 2,
#  'test': './peanuts/test/images',
#  'train': './peanuts/train/images/',
#  'val': './peanuts/valid/images/'}

# %% [markdown]
# # https://github.com/ultralytics/ultralytics
#
# # Setup

# %%
# ultralytics 파일을 설치한다.
# !pip install ultralytics

# %%
import ultralytics
# 버젼체크하기
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.14  Python-3.11.9 torch-2.3.0+cpu CPU (Intel Core(TM) i5-6600 3.30GHz)
# Setup complete  (4 CPUs, 8.0 GB RAM, 156.2/223.0 GB disk)

# %% [markdown]
# # Train (Python version)

# %%
#  YOLOv8n 불러오기

from ultralytics import YOLO

#MS COCO Dataset 사전학습된 yolo8n모델을 로드함
# 다른 모델은 yolo8n 외에도 yolo8s, yolo8m, yolo8l, yolo8x등이 있다
# 그런데 뒤로 갈 수록 정확도는 높아지지만 용량과 처리속도가 느리다
 # load a pretrained YOLOv8n detection model
model=YOLO('yolov8n-seg.pt')

# %%
# 원래 YOLOv8모델의 데이터 이름과 갯수 출력하기
print(type(model.names), len(model.names))
print(model.names)
# Out:
# <class 'dict'> 80
# ...

# %%
# 모델학습하기 data=yaml파일을 넣어준다.
model.train(data='./peanut.yaml', epochs=200, patience=30, batch=32, imgsz=640)
# Out:
# New https://pypi.org/project/ultralytics/8.2.20 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.14  Python-3.11.9 torch-2.3.0+cpu CPU (Intel Core(TM) i5-6600 3.30GHz)
# ...
